# %% [markdown]
# ### AirBnb listings dataset cleaning
# Source: http://insideairbnb.com/get-the-data.html - listings.csv.gz - Detailed Listings data for Barcelona
#
# The specific file used is the one related to the 14th of August 2018. The reason why a 2018 dataset was used is because the analysis will be carried out in relation to Barcelona's average rental prices as provided by the Ajuntament of Barcelona, which are released every year. For obvious reasons the complete data available currently stops at 2018.

# %%
import pandas as pd
import numpy as np

# %%
airbnb_full = pd.read_csv("/home/emanuele/Desktop/IronHack/Projects/Project-Week-2-Barcelona/your-project/listings.csv")

# %% [markdown]
# Given the sheer number of attributes in the listings.csv file it is preferrable to list the columns instead of using head() or describe()

# %%
list(airbnb_full.columns)
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'bed_type',
#  'amenities',
#  'square_feet',
#  'price',
#  'weekly_price',
#  'monthly_price',
#  'security_deposit',
#  'cleaning_fee',
#  'guests_included',
#  'extra_people',
#  'minimum_nights',
#  'maximum_nights',
#  'calendar_updated',
#  'has_availability',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'calendar_last_scraped',
#  'number_of_reviews',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'requires_license',
#  'license',
#  'jurisdiction_names',
#  'instant_bookable',
#  'is_business_travel_ready',
#  'cancellation_policy',
#  'require_guest_profile_picture',
#  'require_guest_phone_verification',
#  'calculated_host_listings_count',
#  'reviews_per_month']

# %% [markdown]
# The columns that will be kept will be related only the data strictly needed for the analysis: 'id', for matters of indexing; 'price', since our analysis will be fully related to the prices of the listings in comparison to rental prices; the columns related to neighbourhood data; 'accomodates', which stores the maximum number of people allowed; 'availability_30', which can be used to determine the percentage of booked days in the 30 days prior to the 14th of August 2018 to better relate the listing price to a rental price, which of course assumes a "booked" percentage of 100%. We will also be using 'room_type' initially to limit the data to listings related to the Entire house, exluding Private and Shared rooms since we assume the prices to be skewed.
#
# Given the presence of 3 different neighbourhood attributes and the possibility of carrying out a more detailed process that doesn't stop at a per-district analysis but goes deeper to a per-neighbourhood one (e.g.: El Clot, La Verneda y La Pau, etc. instead of simply the whole Sant Martì district) we will first check a sample for the aforementioned columns to determine which ones, if not all, are useful in our case.
#
# We will also be checking the different types of listings through the 'room_type' column.

# %%
airbnb_full.loc[:,('neighbourhood',
 'neighbourhood_cleansed',
 'neighbourhood_group_cleansed')].sample(30)
# Out:
#                          neighbourhood          neighbourhood_cleansed  \
# 11842   La Nova Esquerra de l'Eixample  la Nova Esquerra de l'Eixample
# 4591                    Sants-Montjuïc                    el Poble Sec
# 399                 La Sagrada Família              la Sagrada Família
# 10140  L'Antiga Esquerra de l'Eixample  la Nova Esquerra de l'Eixample
# 8434                          El Raval                        el Raval
# 11725                              NaN               la Vila de Gràcia
# 1246               Dreta de l'Eixample          la Dreta de l'Eixample
# 15222                   Sants-Montjuïc                   Sants - Badal
# 14127              Dreta de l'Eixample          la Dreta de l'Eixample
# 14659                         El Gòtic                  el Barri Gòtic
# 11431                     El Poble-sec                    el Poble Sec
# 10968              Dreta de l'Eixample          la Dreta de l'Eixample
# 15627                              NaN          la Dreta de l'Eixample
# 18954               La Sagrada Família              la Sagrada Família
# 5743                           El Clot                         el Clot
# 6496                    La Barceloneta                  la Barceloneta
# 6886          Sant Martí de Provençals        Sant Martí de Provençals
# 7570                          El Gòtic                  el Barri Gòtic
# 18264                   Sants-Montjuïc                           Sants
# 10753   La Nova Esquerra de l'Eixample  la Nova Esquerra de l'Eixample
# 2994             El Besòs i el Maresme           el Besòs i el Maresme
# 14193                      Sant Antoni                     Sant Antoni
# 8224                          El Gòtic                  el Barri Gòtic
# 7554                               NaN  la Nova Esquerra de l'Eixample
# 17230   La Nova Esquerra de l'Eixample  la Nova Esquerra de l'Eixample
# 6093        El Camp de l'Arpa del Clot      el Camp de l'Arpa del Clot
# 16986       El Camp de l'Arpa del Clot      el Camp de l'Arpa del Clot
# 13764               La Sagrada Família              la Sagrada Família
# 8774        La Maternitat i Sant Ramon      la Maternitat i Sant Ramon
# 7431                          El Gòtic                  el Barri Gòtic
#
#       neighbourhood_group_cleansed
# 11842                     Eixample
# 4591                Sants-Montjuïc
# 399                       Eixample
# 10140                     Eixample
# 8434                  Ciutat Vella
# 11725                       Gràcia
# 1246                      Eixample
# 15222               Sants-Montjuïc
# 14127                     Eixample
# 14659                 Ciutat Vella
# 11431               Sants-Montjuïc
# 10968                     Eixample
# 15627                     Eixample
# 18954                     Eixample
# 5743                    Sant Martí
# 6496                  Ciutat Vella
# 6886                    Sant Martí
# 7570                  Ciutat Vella
# 18264               Sants-Montjuïc
# 10753                     Eixample
# 2994                    Sant Martí
# 14193                     Eixample
# 8224                  Ciutat Vella
# 7554                      Eixample
# 17230                     Eixample
# 6093                    Sant Martí
# 16986                   Sant Martí
# 13764                     Eixample
# 8774                     Les Corts
# 7431                  Ciutat Vella

# %%
airbnb_full['room_type'].unique()
# Out:
# array(['Entire home/apt', 'Private room', 'Shared room'], dtype=object)

# %% [markdown]
# We decided to use the cleansed columns given the absence of NaN values. We also confirmed that 'neighborhood_group_cleansed' refers to a district while 'neighborhood_cleansed' refers to the smaller "Barrios".
#
# That said, we proceed with creating a new DataFrame including Entire homes only (since they relate better to a rental house agreement when compared to a Private or Shared room) and then dropping all the unneeded columns.

# %%
airbnb_full = airbnb_full[airbnb_full['room_type'] == 'Entire home/apt']

# %%
airbnb_full = airbnb_full.loc[:,('id', 'neighbourhood_group_cleansed', 'price', 'neighbourhood_cleansed' ,'accommodates','availability_365','last_review','minimum_nights')]

# %% [markdown]
# We decided to cutoff all homes with an available accomodation of more than 6 people to try and limit the effect that apartments renovated as vacation homes (i.e. with more beds or sleeping spaces that a normal house of the same size would accomodate, and therefore more people) will not severely influence our final result

# %%
airbnb_full = airbnb_full[airbnb_full['minimum_nights'] >= 30]

# %%
airbnb_full = airbnb_full[airbnb_full['accommodates'] <= 6]

# %% [markdown]
# The data related to each listing's availability (which will be used in the analysis to weight the listing price when compared to a traditional monthly rental as accurately as possible) is, as explained in the source website, parsed from the calendar on the AirBnb website. This calendar **DOES NOT** discern unavailable days between those caused by a pre-existing booking or a simple choice to make the listing unavailable by the host.
#
# To try and clean the data of listings that have been inactive for a long time as of 2018-08-14 we will be filtering out of all the listings with a last review that dates **more than 2 months before** the date of the parsing. Given the sheer number of observations available we believe that even a timeframe of 2 only months, at least regarding the review, will offer enough data for the analysis to be relevant.

# %% [markdown]
# The next cell's purpose is to check the latest date that a review was added, so that the following slice will respect the 2-months cutoff timeframe.

# %%
airbnb_full.loc[:,('id','last_review')].sort_values('last_review', ascending=False).head()
# Out:
#              id last_review
# 6015   11264883  2018-08-13
# 18799  27472765  2018-08-12
# 14689  23866376  2018-08-11
# 1642    1817640  2018-08-11
# 11589  20264909  2018-08-11

# %% [markdown]
# Slicing the dataframe again. The slice is from the last review date, 2018-08-14, to 2 months prior, 2018-06-14. Also dropping NaN values.

# %%
airbnb_full = airbnb_full[(airbnb_full['last_review'] <= '2018-08-13') & (airbnb_full['last_review'] >= '2018-06-13')]
airbnb_full = airbnb_full[(airbnb_full['last_review'] != np.nan)]

# %% [markdown]
# We can now drop the 'last_review' column since it fulfilled its purpose.

# %%
airbnb_full = airbnb_full.drop('last_review', axis=1)

# %% [markdown]
# Checking prices for possible outliers.

# %%
airbnb_full.sort_values('price', ascending=False).head(50)
# Out:
#              id neighbourhood_group_cleansed   price  \
# 8752   16556943                 Ciutat Vella  $99.00
# 7570   14152120                 Ciutat Vella  $99.00
# 16482  25541279                     Eixample  $99.00
# 5523    9937559                 Ciutat Vella  $99.00
# 120      206846                 Ciutat Vella  $98.00
# 277      417239                       Gràcia  $97.00
# 1576    1691141                     Eixample  $96.00
# 6257   11762804                 Ciutat Vella  $95.00
# 3215    4668430                       Gràcia  $95.00
# 10809  19464663                     Eixample  $95.00
# 2884    3831664                 Ciutat Vella  $95.00
# 5812   10823019                 Ciutat Vella  $95.00
# 12714  21692190                 Ciutat Vella  $94.00
# 8038   15067810               Sants-Montjuïc  $90.00
# 16295  25410568                     Eixample  $90.00
# 6289   11857224                       Gràcia  $90.00
# 6899   13252833                       Gràcia  $90.00
# 6164   11550809                     Eixample  $90.00
# 298      448794                 Ciutat Vella  $90.00
# 5522    9937100                 Ciutat Vella  $89.00
# 13399  22464535               Sants-Montjuïc  $89.00
# 14880  24046259                     Eixample  $89.00
# 15340  24464487                     Eixample  $87.00
# 1753    2003024                 Ciutat Vella  $85.00
# 9299   17425721                 Ciutat Vella  $85.00
# 1710    1916297                       Gràcia  $85.00
# 14563  23718657                     Eixample  $83.00
# 14963  24138826                     Eixample  $82.00
# 9022   17051593                     Eixample  $82.00
# 12477  21393496               Sants-Montjuïc  $80.00
# 12274  21143859                   Sant Martí  $80.00
# 7352   13838321                 Ciutat Vella  $80.00
# 11548  20238733                 Ciutat Vella  $80.00
# 15430  24574630                 Ciutat Vella  $80.00
# 15260  24424771                       Gràcia  $80.00
# 11589  20264909                 Ciutat Vella  $80.00
# 12078  20894086                     Eixample  $80.00
# 3436    5209513                       Gràcia  $80.00
# 700      824902                     Eixample  $80.00
# 15879  25013344                 Ciutat Vella  $80.00
# 858      938557                     Eixample  $80.00
# 2534    3276856                 Ciutat Vella  $80.00
# 14098  23261617                     Eixample  $80.00
# 16425  25506914                     Eixample  $80.00
# 79       144801                 Ciutat Vella  $80.00
# 2933    3936390                       Gràcia  $80.00
# 8949   16951437               Horta-Guinardó  $80.00
# 13595  22756586                 Ciutat Vella  $79.00
# 13179  22199213                     Eixample  $79.00
# 11545  20233640               Horta-Guinardó  $78.00
#
#                       neighbourhood_cleansed  accommodates  availability_365  \
# 8752                          el Barri Gòtic             4               305
# 7570                          el Barri Gòtic             4               239
# 16482                     la Sagrada Família             3                34
# 5523                          el Barri Gòtic             6               316
# 120    Sant Pere, Santa Caterina i la Ribera             2               220
# 277                        la Vila de Gràcia             5               287
# 1576          la Nova Esquerra de l'Eixample             5               363
# 6257                          el Barri Gòtic             2               321
# 3215                       la Vila de Gràcia             4               276
# 10809                 la Dreta de l'Eixample             6               128
# 2884   Sant Pere, Santa Caterina i la Ribera             5               365
# 5812   Sant Pere, Santa Caterina i la Ribera             4               225
# 12714                         el Barri Gòtic             6               365
# 8038                            el Poble Sec             4               281
# 16295                            Sant Antoni             4                90
# 6289                       la Vila de Gràcia             2               257
# 6899                       la Vila de Gràcia             2               212
# 6164                             Sant Antoni             4                50
# 298                                 el Raval             6               363
# 5522                          el Barri Gòtic             4               235
# 13399                           el Poble Sec             4               185
# 14880                            Sant Antoni             4               213
# 15340                            Sant Antoni             6               365
# 1753                          el Barri Gòtic             5               319
# 9299   Sant Pere, Santa Caterina i la Ribera             6                75
# 1710                       la Vila de Gràcia             4                 0
# 14563        l'Antiga Esquerra de l'Eixample             4               304
# 14963                            Sant Antoni             4               257
# 9022         l'Antiga Esquerra de l'Eixample             4               289
# 12477                                  Sants             4               331
# 12274               Sant Martí de Provençals             4               347
# 7352                          el Barri Gòtic             4               327
# 11548  Sant Pere, Santa Caterina i la Ribera             2               304
# 15430  Sant Pere, Santa Caterina i la Ribera             6               331
# 15260              Vallcarca i els Penitents             2               163
# 11589  Sant Pere, Santa Caterina i la Ribera             2                37
# 12078        l'Antiga Esquerra de l'Eixample             4               143
# 3436                       la Vila de Gràcia             2               314
# 700                       la Sagrada Família             5               236
# 15879                         el Barri Gòtic             5               228
# 858                              Sant Antoni             2               117
# 2534                                el Raval             3               225
# 14098                          el Fort Pienc             5               343
# 16425                 la Dreta de l'Eixample             4               128
# 79     Sant Pere, Santa Caterina i la Ribera             4               331
# 2933               Vallcarca i els Penitents             3               293
# 8949                               el Carmel             3               257
# 13595                         el Barri Gòtic             4               272
# 13179        l'Antiga Esquerra de l'Eixample             4               163
# 11545                              el Carmel             4                33
#
#        minimum_nights
# 8752               31
# 7570               31
# 16482              31
# 5523               31
# 120                31
# 277                30
# 1576               30
# 6257               32
# 3215               32
# 10809              32
# 2884               32
# 5812               32
# 12714              32
# 8038               32
# 16295              30
# 6289               31
# 6899               31
# 6164               32
# 298                30
# 5522               31
# 13399              31
# 14880              31
# 15340              32
# 1753               31
# 9299               32
# 1710               31
# 14563              30
# 14963              31
# 9022               32
# 12477              32
# 12274              31
# 7352               32
# 11548              31
# 15430              31
# 15260              32
# 11589              31
# 12078              32
# 3436               31
# 700                32
# 15879              31
# 858                32
# 2534               31
# 14098              33
# 16425              31
# 79                 30
# 2933               32
# 8949               32
# 13595              31
# 13179              32
# 11545              30

# %% [markdown]
# Given the sorting the prices are currently saved as a string. Since they are shown with a "$" sign we will need to drop it to convert the type to int.

# %%
airbnb_full['price'] = airbnb_full['price'].replace("\$", "", regex=True)
airbnb_full['price'] = airbnb_full['price'].replace(",", "", regex=True)

# %% [markdown]
# Converting to int

# %%
airbnb_full['price'] = pd.to_numeric(airbnb_full['price'])

# %% [markdown]
# Checking for outliers on high prices.

# %%
airbnb_full.sort_values('price', ascending=False)
# Out:
#              id neighbourhood_group_cleansed  price  \
# 8732   16506765                 Ciutat Vella  220.0
# 14079  23244848                 Ciutat Vella  200.0
# 14691  23868358                 Ciutat Vella  199.0
# 7229   13694580                 Ciutat Vella  190.0
# 7323   13811701                     Eixample  180.0
# 6800   13103577                 Ciutat Vella  180.0
# 16600  25712520                 Ciutat Vella  172.0
# 9098   17195079                 Ciutat Vella  169.0
# 18794  27471887                 Ciutat Vella  160.0
# 7612   14209613                 Ciutat Vella  155.0
# 5640   10238081                 Ciutat Vella  153.0
# 2686    3493834                     Eixample  150.0
# 16460  25527629                     Eixample  150.0
# 15215  24388074                 Ciutat Vella  150.0
# 4981    8517753                 Ciutat Vella  140.0
# 6935   13279313                 Ciutat Vella  139.0
# 702      827250                     Eixample  135.0
# 16911  26007283                 Ciutat Vella  135.0
# 17613  26613190                 Ciutat Vella  130.0
# 15637  24796633                     Eixample  130.0
# 11113  19747988                 Ciutat Vella  129.0
# 2100    2530059                 Ciutat Vella  125.0
# 8963   16967971                 Ciutat Vella  125.0
# 5845   10891462                     Eixample  122.0
# 8615   16342064                 Ciutat Vella  120.0
# 5181    9048372                    Les Corts  119.0
# 6124   11428143                 Ciutat Vella  117.0
# 7677   14308198                 Ciutat Vella  116.0
# 15036  24217003                 Ciutat Vella  115.0
# 4242    6943632                   Sant Martí  115.0
# ...         ...                          ...    ...
# 11038  19689758                 Ciutat Vella   31.0
# 10799  19449109                 Ciutat Vella   30.0
# 5665   10374992                 Ciutat Vella   30.0
# 8124   15321574                   Nou Barris   30.0
# 14613  23776646                 Ciutat Vella   30.0
# 10032  18542083                 Ciutat Vella   30.0
# 14753  23922829                 Ciutat Vella   30.0
# 1545    1642736               Sants-Montjuïc   30.0
# 5582   10078923                 Ciutat Vella   29.0
# 5631   10203560                 Ciutat Vella   29.0
# 5632   10203916                 Ciutat Vella   29.0
# 12692  21658948                 Ciutat Vella   29.0
# 8922   16919723                 Ciutat Vella   28.0
# 7024   13404925                 Ciutat Vella   27.0
# 6300   11876782                 Ciutat Vella   27.0
# 13594  22756444                 Ciutat Vella   27.0
# 8342   15826346                 Ciutat Vella   27.0
# 7387   13888140                 Ciutat Vella   27.0
# 2305    2930798                 Ciutat Vella   27.0
# 3739    5908217                   Sant Martí   26.0
# 333      484390                     Eixample   25.0
# 16905  26000199               Sants-Montjuïc   25.0
# 8131   15338191                 Ciutat Vella   25.0
# 11698  20401746          Sarrià-Sant Gervasi   15.0
# 10548  19171251               Sants-Montjuïc   10.0
# 6570   12588632                     Eixample   10.0
# 13527  22668646                 Ciutat Vella   10.0
# 2990    4054602               Horta-Guinardó   10.0
# 11917  20717011               Horta-Guinardó   10.0
# 10549  19172215               Sants-Montjuïc   10.0
#
#                       neighbourhood_cleansed  accommodates  availability_365  \
# 8732                          la Barceloneta             2               171
# 14079                         la Barceloneta             2               267
# 14691                               el Raval             4               174
# 7229                                el Raval             2               125
# 7323                  la Dreta de l'Eixample             4               321
# 6800                          el Barri Gòtic             6               365
# 16600                         la Barceloneta             2               173
# 9098   Sant Pere, Santa Caterina i la Ribera             6               175
# 18794                               el Raval             4               133
# 7612   Sant Pere, Santa Caterina i la Ribera             4               365
# 5640   Sant Pere, Santa Caterina i la Ribera             6               301
# 2686                           el Fort Pienc             3               243
# 16460                     la Sagrada Família             5                43
# 15215                         la Barceloneta             3               333
# 4981                          el Barri Gòtic             4               349
# 6935                          el Barri Gòtic             6               222
# 702                       la Sagrada Família             4               220
# 16911  Sant Pere, Santa Caterina i la Ribera             6               361
# 17613                               el Raval             3               111
# 15637                 la Dreta de l'Eixample             4               283
# 11113                         el Barri Gòtic             6               243
# 2100                                el Raval             3               239
# 8963   Sant Pere, Santa Caterina i la Ribera             6               105
# 5845          la Nova Esquerra de l'Eixample             5               359
# 8615   Sant Pere, Santa Caterina i la Ribera             4               356
# 5181              la Maternitat i Sant Ramon             6               365
# 6124                          el Barri Gòtic             6               257
# 7677                                el Raval             2               338
# 15036                               el Raval             6               296
# 4242                             el Poblenou             4               355
# ...                                      ...           ...               ...
# 11038                               el Raval             2               312
# 10799                         el Barri Gòtic             4                74
# 5665   Sant Pere, Santa Caterina i la Ribera             2               150
# 8124                                  Verdun             2               296
# 14613                         el Barri Gòtic             3               114
# 10032                         el Barri Gòtic             3                69
# 14753                               el Raval             2               225
# 1545                                   Sants             3               235
# 5582                          la Barceloneta             2               257
# 5631                          la Barceloneta             2               207
# 5632                          la Barceloneta             2               238
# 12692                         el Barri Gòtic             2                52
# 8922                          el Barri Gòtic             2                50
# 7024                          el Barri Gòtic             2               210
# 6300                          el Barri Gòtic             3               120
# 13594                         el Barri Gòtic             2                95
# 8342                          el Barri Gòtic             2               162
# 7387                          el Barri Gòtic             2                68
# 2305                          la Barceloneta             2               282
# 3739                   el Besòs i el Maresme             4               146
# 333                       la Sagrada Família             2               114
# 16905                           el Poble Sec             1               134
# 8131                          el Barri Gòtic             2                95
# 11698                                 Sarrià             3               318
# 10548                           el Poble Sec             3               365
# 6570                      la Sagrada Família             4               356
# 13527  Sant Pere, Santa Caterina i la Ribera             4               364
# 2990                                Can Baró             3               365
# 11917                              el Carmel             2               237
# 10549                           el Poble Sec             4               342
#
#        minimum_nights
# 8732               32
# 14079              32
# 14691              32
# 7229               32
# 7323               32
# 6800               32
# 16600              31
# 9098               32
# 18794              31
# 7612               32
# 5640               31
# 2686               32
# 16460              31
# 15215              32
# 4981               32
# 6935               31
# 702                32
# 16911              32
# 17613              31
# 15637              31
# 11113              31
# 2100               31
# 8963               31
# 5845               32
# 8615               32
# 5181               32
# 6124               32
# 7677               31
# 15036              32
# 4242               32
# ...               ...
# 11038              31
# 10799              32
# 5665               32
# 8124               31
# 14613              32
# 10032              64
# 14753              31
# 1545               32
# 5582               31
# 5631               31
# 5632               31
# 12692              32
# 8922               33
# 7024               32
# 6300               32
# 13594              32
# 8342               32
# 7387               64
# 2305               31
# 3739               32
# 333                31
# 16905              31
# 8131               32
# 11698              31
# 10548              31
# 6570               31
# 13527              31
# 2990               31
# 11917              31
# 10549              31
#
# [355 rows x 7 columns]

# %% [markdown]
# Creating a new column for "revenue", which will simply be the price multiplied by the actual number of booked days (calculated as 30 - availability_30) to estimate a monthly revenue and compare it with the rental prices.

# %%
map_func = lambda x: round((x['price'] * (365 - x['availability_365']))/12, 2)
airbnb_full['revenue'] = airbnb_full.apply(map_func, axis = 1)

# %%
price_by_district = round(airbnb_full.groupby(['neighbourhood_group_cleansed']).mean(),2)
price_by_district
# Out:
#                                        id  price  accommodates  \
# neighbourhood_group_cleansed
# Ciutat Vella                  15951497.43  68.64          3.44
# Eixample                      16679385.24  72.30          3.75
# Gràcia                        13121482.21  70.00          3.68
# Horta-Guinardó                17806375.17  48.33          2.83
# Les Corts                      8624766.50  81.00          5.00
# Nou Barris                    20772098.67  46.00          3.33
# Sant Andreu                   20929894.00  47.50          3.00
# Sant Martí                    17285030.22  61.03          3.97
# Sants-Montjuïc                17093859.89  57.11          3.33
# Sarrià-Sant Gervasi           13415083.75  59.38          3.25
#
#                               availability_365  minimum_nights  revenue
# neighbourhood_group_cleansed
# Ciutat Vella                            246.50           34.94   644.72
# Eixample                                241.73           32.06   754.13
# Gràcia                                  225.21           31.64   808.24
# Horta-Guinardó                          207.83           31.33   789.11
# Les Corts                               226.75           31.50   643.02
# Nou Barris                              189.33           31.33   767.61
# Sant Andreu                             170.50           33.50   712.08
# Sant Martí                              256.09           33.03   526.14
# Sants-Montjuïc                          233.67           32.96   645.17
# Sarrià-Sant Gervasi                     273.00           31.50   514.33

# %%
price_by_district = pd.DataFrame(price_by_district.loc[:,'revenue'])
price_by_district.to_csv('price_by_district.csv')

# %%
test = airbnb_full['availability_30'].iloc[:50]
test
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'availability_30'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-145-f0a38d52c5f7> in <module>
# ----> 1 test = airbnb_full['availability_30'].iloc[:50]
#       2 test
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'availability_30'

# %%
test2 = test
test

# %%
for index in range(0, len(test)):
    if index == 0:
        if test.iloc[index] < 10:
            test.iloc[index] = np.nan
    else:
        if test.iloc[index] < 10:
            if not test.iloc[index - 1] >= 10:
                test.iloc[index] = np.nan
            else:
                test.iloc[index] = test.iloc[index - 1]
        
            
    
test

# %%
test
