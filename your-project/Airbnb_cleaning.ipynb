# %% [markdown]
# ### AirBnb listings dataset cleaning
# Source: http://insideairbnb.com/get-the-data.html - listings.csv.gz - Detailed Listings data for Barcelona
#
# The specific file used is the one related to the 14th of August 2018. The reason why a 2018 dataset was used is because the analysis will be carried out in relation to Barcelona's average rental prices as provided by the Ajuntament of Barcelona, which are released every year. For obvious reasons the complete data available currently stops at 2018.

# %%
import pandas as pd
import numpy as np
import matplotlib as pyplot

# %%
airbnb_full = pd.read_csv("/home/emanuele/Desktop/IronHack/Projects/Project-Week-2-Barcelona/your-project/listings_jun.csv")

# %% [markdown]
# Given the sheer number of attributes in the listings.csv file it is preferrable to list the columns instead of using head() or describe()

# %%
list(airbnb_full.columns)
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'bed_type',
#  'amenities',
#  'square_feet',
#  'price',
#  'weekly_price',
#  'monthly_price',
#  'security_deposit',
#  'cleaning_fee',
#  'guests_included',
#  'extra_people',
#  'minimum_nights',
#  'maximum_nights',
#  'calendar_updated',
#  'has_availability',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'calendar_last_scraped',
#  'number_of_reviews',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'requires_license',
#  'license',
#  'jurisdiction_names',
#  'instant_bookable',
#  'is_business_travel_ready',
#  'cancellation_policy',
#  'require_guest_profile_picture',
#  'require_guest_phone_verification',
#  'calculated_host_listings_count',
#  'reviews_per_month']

# %% [markdown]
# The columns that will be kept will be related only the data strictly needed for the analysis: 'id', for matters of indexing; 'price', since our analysis will be fully related to the prices of the listings in comparison to rental prices; the columns related to neighbourhood data; 'accomodates', which stores the maximum number of people allowed; 'availability_30', which can be used to determine the percentage of booked days in the 30 days prior to the 14th of August 2018 to better relate the listing price to a rental price, which of course assumes a "booked" percentage of 100%. We will also be using 'room_type' initially to limit the data to listings related to the Entire house, exluding Private and Shared rooms since we assume the prices to be skewed.
#
# Given the presence of 3 different neighbourhood attributes and the possibility of carrying out a more detailed process that doesn't stop at a per-district analysis but goes deeper to a per-neighbourhood one (e.g.: El Clot, La Verneda y La Pau, etc. instead of simply the whole Sant Martì district) we will first check a sample for the aforementioned columns to determine which ones, if not all, are useful in our case.
#
# We will also be checking the different types of listings through the 'room_type' column.

# %%
airbnb_full.loc[:,('neighbourhood',
 'neighbourhood_cleansed',
 'neighbourhood_group_cleansed')].sample(30)
# Out:
#                          neighbourhood                 neighbourhood_cleansed  \
# 16956       El Camp de l'Arpa del Clot             el Camp de l'Arpa del Clot
# 9451                    Vila de Gràcia                      la Vila de Gràcia
# 1441                          El Raval                         el Barri Gòtic
# 4299                La Sagrada Família                     la Sagrada Família
# 377                                NaN                     la Sagrada Família
# 3450           Provençals del Poblenou                Provençals del Poblenou
# 13328                   La Barceloneta                         la Barceloneta
# 5825                          Guinardó                            el Guinardó
# 1753               Dreta de l'Eixample                 la Dreta de l'Eixample
# 5982                          El Raval                               el Raval
# 13646            El Besòs i el Maresme                  el Besòs i el Maresme
# 13414                   Sants-Montjuïc                          Sants - Badal
# 3347                La Sagrada Família                     la Sagrada Família
# 6597                           El Born  Sant Pere, Santa Caterina i la Ribera
# 16715                   Sants-Montjuïc                             la Bordeta
# 5514               Dreta de l'Eixample                 la Dreta de l'Eixample
# 9974                          El Gòtic                         el Barri Gòtic
# 13460                   Sants-Montjuïc                                  Sants
# 1943               Dreta de l'Eixample                 la Dreta de l'Eixample
# 15440                              NaN                 la Dreta de l'Eixample
# 4450   L'Antiga Esquerra de l'Eixample        l'Antiga Esquerra de l'Eixample
# 5712                               NaN  Sant Pere, Santa Caterina i la Ribera
# 7751                  El Baix Guinardó                       el Baix Guinardó
# 9070                               NaN                               el Raval
# 3549    La Nova Esquerra de l'Eixample         la Nova Esquerra de l'Eixample
# 16100                          El Born  Sant Pere, Santa Caterina i la Ribera
# 12869            El Besòs i el Maresme                  el Besòs i el Maresme
# 13763  L'Antiga Esquerra de l'Eixample         la Nova Esquerra de l'Eixample
# 15781  L'Antiga Esquerra de l'Eixample        l'Antiga Esquerra de l'Eixample
# 17077                   La Barceloneta                         la Barceloneta
#
#       neighbourhood_group_cleansed
# 16956                   Sant Martí
# 9451                        Gràcia
# 1441                  Ciutat Vella
# 4299                      Eixample
# 377                       Eixample
# 3450                    Sant Martí
# 13328                 Ciutat Vella
# 5825                Horta-Guinardó
# 1753                      Eixample
# 5982                  Ciutat Vella
# 13646                   Sant Martí
# 13414               Sants-Montjuïc
# 3347                      Eixample
# 6597                  Ciutat Vella
# 16715               Sants-Montjuïc
# 5514                      Eixample
# 9974                  Ciutat Vella
# 13460               Sants-Montjuïc
# 1943                      Eixample
# 15440                     Eixample
# 4450                      Eixample
# 5712                  Ciutat Vella
# 7751                Horta-Guinardó
# 9070                  Ciutat Vella
# 3549                      Eixample
# 16100                 Ciutat Vella
# 12869                   Sant Martí
# 13763                     Eixample
# 15781                     Eixample
# 17077                 Ciutat Vella

# %%
airbnb_full['room_type'].unique()
# Out:
# array(['Entire home/apt', 'Private room', 'Shared room'], dtype=object)

# %% [markdown]
# We decided to use the cleansed columns given the absence of NaN values. We also confirmed that 'neighborhood_group_cleansed' refers to a district while 'neighborhood_cleansed' refers to the smaller "Barrios".
#
# That said, we proceed with creating a new DataFrame including Entire homes only (since they relate better to a rental house agreement when compared to a Private or Shared room) and then dropping all the unneeded columns.

# %%
airbnb_full = airbnb_full[airbnb_full['room_type'] == 'Entire home/apt']

# %%
airbnb_full = airbnb_full.loc[:,('id', 'neighbourhood_group_cleansed', 'price', 'neighbourhood_cleansed' ,'accommodates','availability_60','last_review','minimum_nights')]

# %% [markdown]
# We decided to cutoff all homes with an available accomodation of more than 6 people to try and limit the effect that apartments renovated as vacation homes (i.e. with more beds or sleeping spaces that a normal house of the same size would accomodate, and therefore more people) will not severely influence our final result

# %%
airbnb_full = airbnb_full[airbnb_full['accommodates'] <= 6]

# %% [markdown]
# The data related to each listing's availability (which will be used in the analysis to weight the listing price when compared to a traditional monthly rental as accurately as possible) is, as explained in the source website, parsed from the calendar on the AirBnb website. This calendar **DOES NOT** discern unavailable days between those caused by a pre-existing booking or a simple choice to make the listing unavailable by the host.
#
# To try and clean the data of listings that have been inactive for a long time as of 2018-08-14 we will be filtering out of all the listings with a last review that dates **more than 2 months before** the date of the parsing. Given the sheer number of observations available we believe that even a timeframe of 2 only months, at least regarding the review, will offer enough data for the analysis to be relevant.

# %% [markdown]
# The next cell's purpose is to check the latest date that a review was added, so that the following slice will respect the 2-months cutoff timeframe.

# %%
airbnb_full.loc[:,('id','last_review')].sort_values('last_review', ascending=False).head()
# Out:
#              id last_review
# 6166   11685016  2018-06-08
# 11679  20431737  2018-06-08
# 3553    5392353  2018-06-08
# 11271  19957204  2018-06-08
# 15584  24722608  2018-06-08

# %% [markdown]
# Slicing the dataframe again. The slice is from the last review date, 2018-08-14, to 2 months prior, 2018-06-14. Also dropping NaN values.

# %%
airbnb_full = airbnb_full[(airbnb_full['last_review'] <= '2018-06-08') & (airbnb_full['last_review'] >= '2018-04-08')]
airbnb_full = airbnb_full[(airbnb_full['last_review'] != np.nan)]

# %% [markdown]
# We can now drop the 'last_review' column since it fulfilled its purpose.

# %%
airbnb_full = airbnb_full.drop('last_review', axis=1)

# %% [markdown]
# Checking prices for possible outliers.

# %%
airbnb_full.sort_values('price', ascending=False).head(50)
# Out:
#              id neighbourhood_group_cleansed    price  \
# 546      721470                     Eixample  $999.00
# 550      721509                     Eixample  $999.00
# 13079  22033469                     Eixample  $999.00
# 4204    6819336                     Eixample   $99.00
# 3020    4213133                 Ciutat Vella   $99.00
# 5233    9237132                 Ciutat Vella   $99.00
# 8304   15893888                     Eixample   $99.00
# 4008    6507867                     Eixample   $99.00
# 4280    6962648                     Eixample   $99.00
# 925     1010589               Sants-Montjuïc   $99.00
# 11774  20550128                       Gràcia   $99.00
# 7735   14497583          Sarrià-Sant Gervasi   $99.00
# 4268    6928578                   Sant Martí   $99.00
# 3021    4213287                 Ciutat Vella   $99.00
# 7696   14427537                 Ciutat Vella   $99.00
# 3019    4212985                 Ciutat Vella   $99.00
# 1650    1867951                     Eixample   $99.00
# 7517   14152120                 Ciutat Vella   $99.00
# 2527    3296173                     Eixample   $99.00
# 1823    2127975                       Gràcia   $99.00
# 3013    4208225                 Ciutat Vella   $99.00
# 15019  24229647                 Ciutat Vella   $99.00
# 2890    3886855                     Eixample   $99.00
# 7304   13853887               Horta-Guinardó   $99.00
# 12220  21101215                     Eixample   $99.00
# 949     1027732               Sants-Montjuïc   $99.00
# 15266  24448276                       Gràcia   $99.00
# 1852    2185625               Sants-Montjuïc   $99.00
# 15353  24487331               Sants-Montjuïc   $99.00
# 1313    1343928                       Gràcia   $99.00
# 8582   16438344                     Eixample   $99.00
# 3524    5337674                     Eixample   $99.00
# 15490  24639484                 Ciutat Vella   $99.00
# 10101  18747430                   Sant Martí   $99.00
# 1403    1445152                   Sant Martí   $99.00
# 4703    7867341                   Sant Martí   $99.00
# 4740    7953354               Sants-Montjuïc   $99.00
# 4497    7436791                 Ciutat Vella   $99.00
# 3341    4949743                     Eixample   $99.00
# 13187  22222897                 Ciutat Vella   $99.00
# 2456    3195806                     Eixample   $99.00
# 13397  22510985                 Ciutat Vella   $99.00
# 1481    1580522                     Eixample   $99.00
# 10092  18732436                 Ciutat Vella   $99.00
# 10155  18794665                       Gràcia   $99.00
# 5089    8811813               Sants-Montjuïc   $99.00
# 5107    8881364               Sants-Montjuïc   $99.00
# 5108    8882078               Sants-Montjuïc   $99.00
# 2458    3196697                     Eixample   $99.00
# 5146    8999630                     Eixample   $99.00
#
#                       neighbourhood_cleansed  accommodates  availability_60  \
# 546                            el Fort Pienc             2               58
# 550                   la Dreta de l'Eixample             4               38
# 13079         la Nova Esquerra de l'Eixample             6                0
# 4204                  la Dreta de l'Eixample             5               11
# 3020                                el Raval             6                1
# 5233                                el Raval             4               20
# 8304                             Sant Antoni             6               31
# 4008                      la Sagrada Família             4               51
# 4280                           el Fort Pienc             3               39
# 925                             el Poble Sec             6                9
# 11774                      la Vila de Gràcia             4               42
# 7735                    el Putxet i el Farró             5               41
# 4268       el Parc i la Llacuna del Poblenou             2                7
# 3021                                el Raval             6                3
# 7696   Sant Pere, Santa Caterina i la Ribera             2               34
# 3019                                el Raval             6                0
# 1650                      la Sagrada Família             2                6
# 7517                          el Barri Gòtic             4               14
# 2527                  la Dreta de l'Eixample             4               15
# 1823                       la Vila de Gràcia             4               14
# 3013                                el Raval             6                4
# 15019                         el Barri Gòtic             2               12
# 2890                  la Dreta de l'Eixample             5                9
# 7304                        el Baix Guinardó             4                0
# 12220                 la Dreta de l'Eixample             4               33
# 949                             el Poble Sec             3                7
# 15266     el Camp d'en Grassot i Gràcia Nova             4               15
# 1852                   la Font de la Guatlla             5               33
# 15353                           el Poble Sec             4               40
# 1313      el Camp d'en Grassot i Gràcia Nova             6               54
# 8582          la Nova Esquerra de l'Eixample             5               44
# 3524                  la Dreta de l'Eixample             5               40
# 15490                         la Barceloneta             2                0
# 10101      el Parc i la Llacuna del Poblenou             4               10
# 1403           la Vila Olímpica del Poblenou             6               20
# 4703              el Camp de l'Arpa del Clot             4               46
# 4740                            el Poble Sec             4               12
# 4497                          el Barri Gòtic             2               13
# 3341         l'Antiga Esquerra de l'Eixample             5               17
# 13187                         el Barri Gòtic             3               53
# 2456                             Sant Antoni             4               20
# 13397                         el Barri Gòtic             4               23
# 1481                      la Sagrada Família             6                4
# 10092                               el Raval             4               20
# 10155                      la Vila de Gràcia             2               41
# 5089                                   Sants             5                4
# 5107                                   Sants             5                2
# 5108                                   Sants             5                5
# 2458                             Sant Antoni             4               10
# 5146         l'Antiga Esquerra de l'Eixample             5               14
#
#        minimum_nights
# 546                 3
# 550                 3
# 13079             120
# 4204                4
# 3020                2
# 5233                2
# 8304                4
# 4008                2
# 4280                4
# 925                 3
# 11774               2
# 7735                3
# 4268                2
# 3021                2
# 7696                3
# 3019                2
# 1650                2
# 7517               31
# 2527                4
# 1823                1
# 3013                2
# 15019               5
# 2890                2
# 7304                4
# 12220               3
# 949                 3
# 15266               2
# 1852                2
# 15353               3
# 1313                3
# 8582                2
# 3524                3
# 15490               2
# 10101               2
# 1403                3
# 4703                2
# 4740                2
# 4497                3
# 3341                2
# 13187               1
# 2456                2
# 13397               7
# 1481                3
# 10092               3
# 10155               1
# 5089                2
# 5107                2
# 5108                2
# 2458                2
# 5146                2

# %% [markdown]
# Given the sorting the prices are currently saved as a string. Since they are shown with a "$" sign we will need to drop it to convert the type to int.

# %%
airbnb_full['price'] = airbnb_full['price'].replace("\$", "", regex=True)
airbnb_full['price'] = airbnb_full['price'].replace(",", "", regex=True)

# %% [markdown]
# Converting to int

# %%
airbnb_full['price'] = pd.to_numeric(airbnb_full['price'])

# %% [markdown]
# Checking for outliers on high prices.

# %%
airbnb_full.sort_values('price', ascending=False)
# Out:
#              id neighbourhood_group_cleansed   price  \
# 8655   16597057                    Les Corts  3000.0
# 8660   16607374                    Les Corts  3000.0
# 8661   16607759                    Les Corts  3000.0
# 13753  22978545               Horta-Guinardó  1180.0
# 13563  22741727                       Gràcia  1000.0
# 13560  22741274                       Gràcia  1000.0
# 6486   12534863               Sants-Montjuïc  1000.0
# 3807    6034571                   Sant Martí  1000.0
# 3808    6035889                   Sant Martí  1000.0
# 8580   16436541                   Sant Martí  1000.0
# 4474    7355148                   Sant Martí  1000.0
# 6483   12533035               Sants-Montjuïc  1000.0
# 13564  22742743                       Gràcia  1000.0
# 13570  22756295                       Gràcia  1000.0
# 13572  22757076                       Gràcia  1000.0
# 15192  24385283                   Sant Martí  1000.0
# 2442    3180157                     Eixample  1000.0
# 13288  22351042                       Gràcia  1000.0
# 13298  22367351                       Gràcia  1000.0
# 32        72436                   Sant Martí  1000.0
# 13559  22740570                       Gràcia  1000.0
# 13299  22367519                       Gràcia  1000.0
# 13558  22740205                       Gràcia  1000.0
# 13294  22365545                       Gràcia  1000.0
# 13295  22365805                       Gràcia  1000.0
# 13296  22366149                       Gràcia  1000.0
# 14975  24196303                     Eixample  1000.0
# 4971    8414793                   Sant Martí  1000.0
# 550      721509                     Eixample   999.0
# 546      721470                     Eixample   999.0
# ...         ...                          ...     ...
# 8044   15270819                    Les Corts    35.0
# 1323    1350129               Sants-Montjuïc    35.0
# 1291    1322421               Sants-Montjuïc    35.0
# 1262    1293396               Sants-Montjuïc    35.0
# 13182  22209008                 Ciutat Vella    35.0
# 7204   13739624          Sarrià-Sant Gervasi    35.0
# 5098    8842446               Horta-Guinardó    35.0
# 2495    3243398               Sants-Montjuïc    35.0
# 1754    2048782                 Ciutat Vella    35.0
# 8491   16246948                     Eixample    34.0
# 14908  24114757               Sants-Montjuïc    34.0
# 6046   11395302                 Ciutat Vella    33.0
# 13580  22767740                   Sant Martí    32.0
# 12143  21003601               Horta-Guinardó    30.0
# 1611    1814248                   Sant Martí    30.0
# 3002    4166058               Sants-Montjuïc    30.0
# 13005  21953528               Sants-Montjuïc    29.0
# 9340   17595202                 Ciutat Vella    29.0
# 11699  20448470               Horta-Guinardó    29.0
# 16127  25103968                       Gràcia    26.0
# 11785  20565812                  Sant Andreu    25.0
# 14742  23952040               Sants-Montjuïc    25.0
# 11898  20721200                   Sant Martí    25.0
# 9737   18254724                     Eixample    20.0
# 12089  20949848                 Ciutat Vella    20.0
# 9484   17837460                 Ciutat Vella    20.0
# 1466    1558596                 Ciutat Vella    19.0
# 3576    5430917               Sants-Montjuïc    15.0
# 2591    3378393                     Eixample    15.0
# 7231   13776433               Sants-Montjuïc    10.0
#
#                              neighbourhood_cleansed  accommodates  \
# 8655                     la Maternitat i Sant Ramon             2
# 8660                     la Maternitat i Sant Ramon             2
# 8661                     la Maternitat i Sant Ramon             2
# 13753                                   el Guinardó             5
# 13563                             la Vila de Gràcia             2
# 13560                             la Vila de Gràcia             5
# 6486                          la Font de la Guatlla             6
# 3807                                    el Poblenou             2
# 3808                                    el Poblenou             6
# 8580                                    el Poblenou             5
# 4474                                    el Poblenou             4
# 6483                          la Font de la Guatlla             4
# 13564                             la Vila de Gràcia             4
# 13570                             la Vila de Gràcia             4
# 13572                             la Vila de Gràcia             4
# 15192  Diagonal Mar i el Front Marítim del Poblenou             4
# 2442                         la Dreta de l'Eixample             6
# 13288                             la Vila de Gràcia             5
# 13298                             la Vila de Gràcia             2
# 32                                      el Poblenou             2
# 13559                             la Vila de Gràcia             5
# 13299                             la Vila de Gràcia             2
# 13558                             la Vila de Gràcia             5
# 13294                             la Vila de Gràcia             5
# 13295                             la Vila de Gràcia             5
# 13296                             la Vila de Gràcia             2
# 14975                            la Sagrada Família             4
# 4971                                    el Poblenou             4
# 550                          la Dreta de l'Eixample             4
# 546                                   el Fort Pienc             2
# ...                                             ...           ...
# 8044                     la Maternitat i Sant Ramon             3
# 1323                                   el Poble Sec             4
# 1291                                   el Poble Sec             4
# 1262                                   el Poble Sec             4
# 13182         Sant Pere, Santa Caterina i la Ribera             2
# 7204                         Sant Gervasi - Galvany             4
# 5098                       Sant Genís dels Agudells             2
# 2495                                   el Poble Sec             2
# 1754          Sant Pere, Santa Caterina i la Ribera             2
# 8491                                    Sant Antoni             4
# 14908                                 Sants - Badal             2
# 6046                                 la Barceloneta             2
# 13580                                   el Poblenou             3
# 12143                                     el Carmel             3
# 1611                          el Besòs i el Maresme             6
# 3002                                   el Poble Sec             6
# 13005                                    la Bordeta             2
# 9340                                 el Barri Gòtic             2
# 11699                                     el Carmel             6
# 16127                                      la Salut             1
# 11785                                 Baró de Viver             2
# 14742                         la Font de la Guatlla             6
# 11898                    el Camp de l'Arpa del Clot             3
# 9737                                    Sant Antoni             2
# 12089                                      el Raval             4
# 9484                                       el Raval             2
# 1466                                       el Raval             6
# 3576                                   el Poble Sec             4
# 2591                                    Sant Antoni             4
# 7231                                   el Poble Sec             2
#
#        availability_60  minimum_nights
# 8655                28               2
# 8660                26               2
# 8661                36               2
# 13753               23               5
# 13563               28               2
# 13560               12               2
# 6486                50               2
# 3807                30               3
# 3808                43               3
# 8580                41               2
# 4474                52               2
# 6483                35               2
# 13564               21               2
# 13570               21               2
# 13572                8               2
# 15192               58               3
# 2442                21               3
# 13288               22               2
# 13298               28               2
# 32                  39               3
# 13559               18               2
# 13299               28               2
# 13558               22               2
# 13294               21               2
# 13295               22               2
# 13296               28               2
# 14975               25               2
# 4971                40               3
# 550                 38               3
# 546                 58               3
# ...                ...             ...
# 8044                35               1
# 1323                39               3
# 1291                37               3
# 1262                29               3
# 13182               12               1
# 7204                 9               2
# 5098                 3               2
# 2495                11               5
# 1754                10               4
# 8491                26               5
# 14908               31               3
# 6046                50              31
# 13580               12               2
# 12143               22               2
# 1611                 3               1
# 3002                24               5
# 13005               39               2
# 9340                22               2
# 11699               32               1
# 16127               15               3
# 11785                4               1
# 14742               37               1
# 11898               56              31
# 9737                 7               1
# 12089                7               1
# 9484                 7               1
# 1466                 0               1
# 3576                38              20
# 2591                60              20
# 7231                34               2
#
# [3553 rows x 7 columns]

# %% [markdown]
# Creating a new column for "revenue", which will simply be the price multiplied by the actual number of booked days (calculated as 30 - availability_30) to estimate a monthly revenue and compare it with the rental prices.

# %%
map_func = lambda x: round((x['price'] * (60 - x['availability_60']))/2, 2)
airbnb_full['revenue'] = airbnb_full.apply(map_func, axis = 1)

# %%
df_min_30 = airbnb_full[airbnb_full['minimum_nights'] >= 30]
df_no_min = airbnb_full[airbnb_full['minimum_nights'] <= 29]

# %%
df_min_30
# Out:
#              id neighbourhood_group_cleansed  price  \
# 280      448794                 Ciutat Vella   90.0
# 468      641603                       Gràcia   95.0
# 611      772319                       Gràcia   40.0
# 619      776174                 Ciutat Vella   60.0
# 1675    1911214                     Eixample   61.0
# 1725    2003024                 Ciutat Vella   85.0
# 2668    3493834                     Eixample  150.0
# 2724    3582210          Sarrià-Sant Gervasi   60.0
# 2864    3841327                     Eixample   68.0
# 2911    3936390                       Gràcia   60.0
# 2985    4134025                 Ciutat Vella   46.0
# 2990    4141367                     Eixample   75.0
# 3235    4668430                       Gràcia   95.0
# 3902    6295222                 Ciutat Vella   40.0
# 4023    6537473                     Eixample   90.0
# 4125    6722427               Sants-Montjuïc   60.0
# 4270    6943632                   Sant Martí  115.0
# 4494    7433126                     Eixample  135.0
# 4521    7509328                       Gràcia   50.0
# 4684    7824065                     Eixample   60.0
# 5520    9937559                 Ciutat Vella   99.0
# 5533    9978245                       Gràcia  100.0
# 5543    9997240                 Ciutat Vella   89.0
# 5664   10398589               Sants-Montjuïc   42.0
# 5811   10891462                     Eixample  126.0
# 5870   11073632                 Ciutat Vella   55.0
# 5888   11116037                 Ciutat Vella  130.0
# 6023   11348543               Sants-Montjuïc   75.0
# 6046   11395302                 Ciutat Vella   33.0
# 6131   11616677                 Ciutat Vella  100.0
# ...         ...                          ...    ...
# 6975   13439317                 Ciutat Vella  228.0
# 7127   13648568                 Ciutat Vella   72.0
# 7155   13678318               Sants-Montjuïc   45.0
# 7517   14152120                 Ciutat Vella   99.0
# 7693   14422065                     Eixample   45.0
# 8527   16343201                     Eixample  100.0
# 8556   16387031                   Sant Martí   70.0
# 8618   16506765                 Ciutat Vella  220.0
# 8636   16556943                 Ciutat Vella   99.0
# 8670   16641407                     Eixample   46.0
# 8671   16644125                 Ciutat Vella   56.0
# 8905   17081942                   Sant Martí   49.0
# 9568   17998983                 Ciutat Vella   50.0
# 9748   18267234                 Ciutat Vella  150.0
# 9753   18271246                 Ciutat Vella   80.0
# 10764  19464663                     Eixample  189.0
# 11052  19747988                 Ciutat Vella  129.0
# 11220  19918005                 Ciutat Vella  170.0
# 11548  20264909                 Ciutat Vella   80.0
# 11644  20379931                     Eixample  175.0
# 11798  20595573                 Ciutat Vella  160.0
# 11898  20721200                   Sant Martí   25.0
# 12481  21420677                 Ciutat Vella  100.0
# 13079  22033469                     Eixample  999.0
# 13362  22458687                 Ciutat Vella   65.0
# 13557  22739717                 Ciutat Vella   65.0
# 14111  23317172                 Ciutat Vella  115.0
# 14485  23685724               Sants-Montjuïc  100.0
# 14830  24034629                     Eixample   90.0
# 15381  24516101                   Sant Martí   98.0
#
#                       neighbourhood_cleansed  accommodates  availability_60  \
# 280                                 el Raval             6                7
# 468                        la Vila de Gràcia             2               36
# 611                                 la Salut             4                0
# 619                           el Barri Gòtic             4                2
# 1675                  la Dreta de l'Eixample             4                0
# 1725                          el Barri Gòtic             5                1
# 2668                           el Fort Pienc             3                6
# 2724                  Sant Gervasi - Galvany             5                0
# 2864                  la Dreta de l'Eixample             4                6
# 2911               Vallcarca i els Penitents             3               21
# 2985                                el Raval             4                1
# 2990          la Nova Esquerra de l'Eixample             4               19
# 3235                       la Vila de Gràcia             4               10
# 3902                                el Raval             2               25
# 4023                  la Dreta de l'Eixample             2               36
# 4125                            el Poble Sec             2                5
# 4270                             el Poblenou             4                7
# 4494                      la Sagrada Família             4               13
# 4521                       la Vila de Gràcia             3                6
# 4684          la Nova Esquerra de l'Eixample             4               11
# 5520                          el Barri Gòtic             6                0
# 5533                       la Vila de Gràcia             4               10
# 5543                          el Barri Gòtic             4               17
# 5664                            el Poble Sec             3               31
# 5811          la Nova Esquerra de l'Eixample             5               28
# 5870                          la Barceloneta             4                0
# 5888                          el Barri Gòtic             2               10
# 6023                            el Poble Sec             4                4
# 6046                          la Barceloneta             2               50
# 6131                                el Raval             4               59
# ...                                      ...           ...              ...
# 6975                          la Barceloneta             2               23
# 7127   Sant Pere, Santa Caterina i la Ribera             4               39
# 7155                              la Bordeta             4                0
# 7517                          el Barri Gòtic             4               14
# 7693                           el Fort Pienc             2                2
# 8527          la Nova Esquerra de l'Eixample             4                1
# 8556                                 el Clot             5               17
# 8618                          la Barceloneta             2               51
# 8636                          el Barri Gòtic             4                5
# 8670                             Sant Antoni             4               15
# 8671                          el Barri Gòtic             4               29
# 8905              el Camp de l'Arpa del Clot             4               12
# 9568   Sant Pere, Santa Caterina i la Ribera             2                0
# 9748                          la Barceloneta             5               27
# 9753                          la Barceloneta             2               26
# 10764                 la Dreta de l'Eixample             6               30
# 11052                         el Barri Gòtic             6               24
# 11220                               el Raval             2                5
# 11548  Sant Pere, Santa Caterina i la Ribera             2                5
# 11644                 la Dreta de l'Eixample             6               52
# 11798                         la Barceloneta             2               43
# 11898             el Camp de l'Arpa del Clot             3               56
# 12481  Sant Pere, Santa Caterina i la Ribera             3               56
# 13079         la Nova Esquerra de l'Eixample             6                0
# 13362                               el Raval             2               15
# 13557                               el Raval             2               23
# 14111                               el Raval             6               16
# 14485                           el Poble Sec             5                5
# 14830                            Sant Antoni             2                0
# 15381          la Vila Olímpica del Poblenou             6               50
#
#        minimum_nights  revenue
# 280                30   2385.0
# 468                31   1140.0
# 611                32   1200.0
# 619                31   1740.0
# 1675               40   1830.0
# 1725               31   2507.5
# 2668               32   4050.0
# 2724               31   1800.0
# 2864               35   1836.0
# 2911               32   1170.0
# 2985               31   1357.0
# 2990               32   1537.5
# 3235               32   2375.0
# 3902               30    700.0
# 4023               32   1080.0
# 4125               31   1650.0
# 4270               32   3047.5
# 4494               31   3172.5
# 4521               30   1350.0
# 4684               32   1470.0
# 5520               30   2970.0
# 5533               31   2500.0
# 5543               31   1913.5
# 5664               31    609.0
# 5811               32   2016.0
# 5870               32   1650.0
# 5888               30   3250.0
# 6023               31   2100.0
# 6046               31    165.0
# 6131               32     50.0
# ...               ...      ...
# 6975               31   4218.0
# 7127               32    756.0
# 7155               31   1350.0
# 7517               31   2277.0
# 7693               32   1305.0
# 8527               32   2950.0
# 8556               32   1505.0
# 8618               32    990.0
# 8636               31   2722.5
# 8670               31   1035.0
# 8671               92    868.0
# 8905               31   1176.0
# 9568               30   1500.0
# 9748               32   2475.0
# 9753               32   1360.0
# 10764              32   2835.0
# 11052              31   2322.0
# 11220              35   4675.0
# 11548              31   2200.0
# 11644              32    700.0
# 11798              32   1360.0
# 11898              31     50.0
# 12481              32    200.0
# 13079             120  29970.0
# 13362              32   1462.5
# 13557              32   1202.5
# 14111              32   2530.0
# 14485              60   2750.0
# 14830              31   2700.0
# 15381              32    490.0
#
# [69 rows x 8 columns]

# %%
price_by_district_min = round(df_min_30.groupby(['neighbourhood_group_cleansed']).mean(),2)
price_by_district = round(df_no_min.groupby(['neighbourhood_group_cleansed']).mean(),2)

# %%
price_by_district.to_csv('price_by_district.csv')

# %%
price_by_district_min.to_csv('price_by_district_min.csv')

# %%
price_by_district['std'] = round(df_no_min[['neighbourhood_group_cleansed','revenue']].groupby(['neighbourhood_group_cleansed']).std(), 2)

# %%
for index in range(0, len(test)):
    if index == 0:
        if test.iloc[index] < 10:
            test.iloc[index] = np.nan
    else:
        if test.iloc[index] < 10:
            if not test.iloc[index - 1] >= 10:
                test.iloc[index] = np.nan
            else:
                test.iloc[index] = test.iloc[index - 1]
        
            
    
test
