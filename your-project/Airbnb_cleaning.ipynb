# %% [markdown]
# ### AirBnb listings dataset cleaning
# Source: http://insideairbnb.com/get-the-data.html - listings.csv.gz - Detailed Listings data for Barcelona
#
# The specific file used is the one related to the 14th of August 2018. The reason why a 2018 dataset was used is because the analysis will be carried out in relation to Barcelona's average rental prices as provided by the Ajuntament of Barcelona, which are released every year. For obvious reasons the complete data available currently stops at 2018.

# %%
import pandas as pd
import numpy as np

# %%
airbnb_full = pd.read_csv("/home/emanuele/Desktop/IronHack/Projects/Project-Week-2-Barcelona/your-project/listings.csv")

# %% [markdown]
# Given the sheer number of attributes in the listings.csv file it is preferrable to list the columns instead of using head() or describe()

# %%
list(airbnb_full.columns)
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'bed_type',
#  'amenities',
#  'square_feet',
#  'price',
#  'weekly_price',
#  'monthly_price',
#  'security_deposit',
#  'cleaning_fee',
#  'guests_included',
#  'extra_people',
#  'minimum_nights',
#  'maximum_nights',
#  'calendar_updated',
#  'has_availability',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'calendar_last_scraped',
#  'number_of_reviews',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'requires_license',
#  'license',
#  'jurisdiction_names',
#  'instant_bookable',
#  'is_business_travel_ready',
#  'cancellation_policy',
#  'require_guest_profile_picture',
#  'require_guest_phone_verification',
#  'calculated_host_listings_count',
#  'reviews_per_month']

# %% [markdown]
# The columns that will be kept will be related only the data strictly needed for the analysis: 'id', for matters of indexing; 'price', since our analysis will be fully related to the prices of the listings in comparison to rental prices; the columns related to neighbourhood data; 'accomodates', which stores the maximum number of people allowed; 'availability_30', which can be used to determine the percentage of booked days in the 30 days prior to the 14th of August 2018 to better relate the listing price to a rental price, which of course assumes a "booked" percentage of 100%. We will also be using 'room_type' initially to limit the data to listings related to the Entire house, exluding Private and Shared rooms since we assume the prices to be skewed.
#
# Given the presence of 3 different neighbourhood attributes and the possibility of carrying out a more detailed process that doesn't stop at a per-district analysis but goes deeper to a per-neighbourhood one (e.g.: El Clot, La Verneda y La Pau, etc. instead of simply the whole Sant Martì district) we will first check a sample for the aforementioned columns to determine which ones, if not all, are useful in our case.
#
# We will also be checking the different types of listings through the 'room_type' column.

# %%
airbnb_full.loc[:,('neighbourhood',
 'neighbourhood_cleansed',
 'neighbourhood_group_cleansed')].sample(30)
# Out:
#                          neighbourhood                 neighbourhood_cleansed  \
# 15132                              NaN                 la Dreta de l'Eixample
# 10843               La Sagrada Família                     la Sagrada Família
# 10985              Dreta de l'Eixample                 la Dreta de l'Eixample
# 7460   L'Antiga Esquerra de l'Eixample        l'Antiga Esquerra de l'Eixample
# 11069   Turó de la Peira - Can Peguera                    el Turó de la Peira
# 7559                          El Gòtic                         el Barri Gòtic
# 431                     La Barceloneta                         la Barceloneta
# 14282                         El Raval                               el Raval
# 1937    La Nova Esquerra de l'Eixample         la Nova Esquerra de l'Eixample
# 12228               La Sagrada Família                     la Sagrada Família
# 13796                              NaN                 la Dreta de l'Eixample
# 15236         Sant Pere/Santa Caterina  Sant Pere, Santa Caterina i la Ribera
# 4631               Dreta de l'Eixample                 la Dreta de l'Eixample
# 6485                          El Gòtic                         el Barri Gòtic
# 5211               Dreta de l'Eixample                 la Dreta de l'Eixample
# 13712                          El Born  Sant Pere, Santa Caterina i la Ribera
# 18394                   Vila de Gràcia                      la Vila de Gràcia
# 8418                           El Born  Sant Pere, Santa Caterina i la Ribera
# 1197                La Sagrada Família                     la Sagrada Família
# 12777  L'Antiga Esquerra de l'Eixample        l'Antiga Esquerra de l'Eixample
# 13558              Dreta de l'Eixample                 la Dreta de l'Eixample
# 2275                       Sant Antoni                            Sant Antoni
# 10332                          El Clot                                el Clot
# 3519               Dreta de l'Eixample                 la Dreta de l'Eixample
# 6496                    La Barceloneta                         la Barceloneta
# 15826                   Sants-Montjuïc                          Sants - Badal
# 13807   La Nova Esquerra de l'Eixample        l'Antiga Esquerra de l'Eixample
# 4169                             Navas                                  Navas
# 3502                 Glòries - El Parc      el Parc i la Llacuna del Poblenou
# 12255               La Sagrada Família                     la Sagrada Família
#
#       neighbourhood_group_cleansed
# 15132                     Eixample
# 10843                     Eixample
# 10985                     Eixample
# 7460                      Eixample
# 11069                   Nou Barris
# 7559                  Ciutat Vella
# 431                   Ciutat Vella
# 14282                 Ciutat Vella
# 1937                      Eixample
# 12228                     Eixample
# 13796                     Eixample
# 15236                 Ciutat Vella
# 4631                      Eixample
# 6485                  Ciutat Vella
# 5211                      Eixample
# 13712                 Ciutat Vella
# 18394                       Gràcia
# 8418                  Ciutat Vella
# 1197                      Eixample
# 12777                     Eixample
# 13558                     Eixample
# 2275                      Eixample
# 10332                   Sant Martí
# 3519                      Eixample
# 6496                  Ciutat Vella
# 15826               Sants-Montjuïc
# 13807                     Eixample
# 4169                   Sant Andreu
# 3502                    Sant Martí
# 12255                     Eixample

# %%
airbnb_full['room_type'].unique()
# Out:
# array(['Entire home/apt', 'Private room', 'Shared room'], dtype=object)

# %% [markdown]
# We decided to use the cleansed columns given the absence of NaN values. We also confirmed that 'neighborhood_group_cleansed' refers to a district while 'neighborhood_cleansed' refers to the smaller "Barrios".
#
# That said, we proceed with creating a new DataFrame including Entire homes only (since they relate better to a rental house agreement when compared to a Private or Shared room) and then dropping all the unneeded columns.

# %%
airbnb_full = airbnb_full[airbnb_full['room_type'] == 'Entire home/apt']

# %%
airbnb_full = airbnb_full.loc[:,('id', 'neighbourhood_group_cleansed', 'price', 'neighbourhood' ,'accommodates','availability_30','last_review')]

# %% [markdown]
# We decided to cutoff all homes with an available accomodation of more than 6 people to try and limit the effect that apartments renovated as vacation homes (i.e. with more beds or sleeping spaces that a normal house of the same size would accomodate, and therefore more people) will not severely influence our final result

# %%
airbnb_full = airbnb_full[airbnb_full['accommodates'] <= 6]

# %% [markdown]
# The data related to each listing's availability (which will be used in the analysis to weight the listing price when compared to a traditional monthly rental as accurately as possible) is, as explained in the source website, parsed from the calendar on the AirBnb website. This calendar **DOES NOT** discern unavailable days between those caused by a pre-existing booking or a simple choice to make the listing unavailable by the host.
#
# To try and clean the data of listings that have been inactive for a long time as of 2018-08-14 we will be filtering out of all the listings with a last review that dates **more than 2 months before** the date of the parsing. Given the sheer number of observations available we believe that even a timeframe of 2 only months, at least regarding the review, will offer enough data for the analysis to be relevant.

# %% [markdown]
# The next cell's purpose is to confirm that the last date that a review was added to whatever listing matches the date of the parsing, so that the following slice will respect the 2-months cutoff timeframe.

# %%
airbnb_full.loc[:,('id','last_review')].sort_values('last_review', ascending=False).head()
# Out:
#              id last_review
# 4784    8060075  2018-08-13
# 3164    4543132  2018-08-13
# 14714  23890155  2018-08-13
# 6015   11264883  2018-08-13
# 1892    2208080  2018-08-13

# %% [markdown]
# Slicing the dataframe again. The slice is from the last review date, 2018-08-14, to 2 months prior, 2018-06-14. Also dropping NaN values.

# %%
airbnb_full = airbnb_full[(airbnb_full['last_review'] < '2018-08-14') & (airbnb_full['last_review'] > '2018-06-14')]
airbnb_full = airbnb_full[(airbnb_full['last_review'] != np.nan)]

# %% [markdown]
# We can now drop the 'last_review' column since it fulfilled its purpose.

# 2806               Dreta de l'Eixample             6                8
# 2961                       El Poblenou             5                8
# 208                       El Poble-sec             2                0
# 3033                          El Raval             6                0
# 3035                          El Raval             6                0
# 3036                          El Raval             6                0
# 3037                          El Raval             6                0
# 3038                          El Raval             6                0
# 17245              Dreta de l'Eixample             6               27
# 1847                    Vila de Gràcia             4                5
# 3044                          El Raval             6                0
# 14016                     El Poble-sec             6               20
# 16002              Dreta de l'Eixample             5               27
# 15932           Sant Gervasi - Galvany             2               22
# 15367                     El Poble-sec             4               12
# 16451                   Sants-Montjuïc             4               18
# 16482               La Sagrada Família             3                4
# 899     La Nova Esquerra de l'Eixample             6                4
# 963                       El Poble-sec             6                4
# 986                       El Poble-sec             3                3
# 1013                   Les Tres Torres             4                4
# 13183                         El Gòtic             2               26
# 11278                     El Poble-sec             6               13
# 16710              Dreta de l'Eixample             4                2
# 1345   Camp d'en Grassot i Gràcia Nova             6               20
# 1424                  La Vila Olímpica             6                7
# 1507                La Sagrada Família             6                7
# 1670                       El Poblenou             6                3
# 1677                La Sagrada Família             2                6
# 11805                   Vila de Gràcia             4               24
# 1698                    Sants-Montjuïc             5                3
# 11460                     El Poble-sec             6               10
# 3039                          El Raval             6                0

# %% [markdown]
# Given the sorting the prices are currently saved as a string. Since they are shown with a "$" sign we will need to drop it to convert the type to int.

# %%
airbnb_full['price'] = airbnb_full['price'].replace("\$", "", regex=True)

# %% [markdown]
# Converting to int

# %%
airbnb_full['price'] = pd.to_numeric(airbnb_full['price'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "1,000.00"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-e1ca24052cbb> in <module>
# ----> 1 airbnb_full['price'] = pd.to_numeric(airbnb_full['price'])
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.7/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     133             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     134             values = lib.maybe_convert_numeric(values, set(),
# --> 135                                                coerce_numeric=coerce_numeric)
#     136
#     137     except Exception:
#
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "1,000.00" at position 12

# %% [markdown]
# The presence of one of more commas is preventing the conversion, we will therefore remove them.

# %%
airbnb_full['price'] = airbnb_full['price'].replace(",", "", regex=True)

# %%
airbnb_full['price'] = pd.to_numeric(airbnb_full['price'])

# %% [markdown]
# TODO: Random checks on listings with a very high price per night have shows that the price in the dataset **DOES NOT** match the one on the website by a VERY HIGH MARGIN. We will need to do further checks to determine a cutoff value for a price to be considered a real outlier.

# %%
airbnb_full.sort_values('price', ascending=False)
# Out:
#              id neighbourhood_group_cleansed   price  \
# 8773   16607374                    Les Corts  3000.0
# 8774   16607759                    Les Corts  3000.0
# 6549   12534863               Sants-Montjuïc  1000.0
# 13597  22757076                       Gràcia  1000.0
# 13593  22756295                       Gràcia  1000.0
# 13587  22742743                       Gràcia  1000.0
# 13585  22741727                       Gràcia  1000.0
# 13582  22741274                       Gràcia  1000.0
# 13581  22740570                       Gràcia  1000.0
# 13580  22740205                       Gràcia  1000.0
# 2457    3180157                     Eixample  1000.0
# 8685   16436541                   Sant Martí  1000.0
# 13317  22367519                       Gràcia  1000.0
# 13313  22366149                       Gràcia  1000.0
# 13312  22365805                       Gràcia  1000.0
# 13311  22365545                       Gràcia  1000.0
# 4953    8414793                   Sant Martí  1000.0
# 4444    7355148                   Sant Martí  1000.0
# 16633  25762264          Sarrià-Sant Gervasi  1000.0
# 3784    6034571                   Sant Martí  1000.0
# 5632                    La Barceloneta             2                1
# 9409                          El Gòtic             2                6
# 11738                              NaN             6               12
# 12692                         El Gòtic             2                0
# 5582                    La Barceloneta             2                0
# 5631                    La Barceloneta             2               11
# 7933                               NaN             2                2
# 11090  L'Antiga Esquerra de l'Eixample             2               17
# 8342                          El Gòtic             2               18
# 7387                          El Gòtic             2                0
# 13594                         El Gòtic             2               20
# 2305                    La Barceloneta             2                0
# 6300                          El Gòtic             3                0
# 7024                          El Gòtic             2                5
# 3739             El Besòs i el Maresme             4               23
# 3554                      El Poble-sec             4                0
# 16905                     El Poble-sec             1                0
# 333                 La Sagrada Família             2                0
# 8131                          El Gòtic             2                3
# 11815                    Baró de Viver             2                1
# 11698                           Sarrià             3                0
# 11917                           Carmel             2                8
# 6570                La Sagrada Família             4               21
# 2990                          Can Baro             3               30
# 10548                     El Poble-sec             3               30
# 13527                          El Born             4               29
# 10549                     El Poble-sec             4                7
#
# [3751 rows x 6 columns]

# %% [markdown]
# Creating a new column for "revenue", which will simply be the price multiplied by the actual number of booked days (calculated as 30 - availability_30) to estimate a monthly revenue and compare it with the rental prices.

# %%
map_func = lambda x: 30 - airbnb_full['availability_30']

# %%
df = airbnb_full

# %%
df['revenue']
# Out:
# 0        0        29
# 8        24
# 9        24
# 10       1...
# 8        0        29
# 8        24
# 9        24
# 10       1...
# 9        0        29
# 8        24
# 9        24
# 10       1...
# 10       0        29
# 8        24
# 9        24
# 10       1...
# 11       0        29
# 8        24
# 9        24
# 10       1...
# 19       0        29
# 8        24
# 9        24
# 10       1...
# 20       0        29
# 8        24
# 9        24
# 10       1...
# 26       0        29
# 8        24
# 9        24
# 10       1...
# 27       0        29
# 8        24
# 9        24
# 10       1...
# 28       0        29
# 8        24
# 9        24
# 10       1...
# 33       0        29
# 8        24
# 9        24
# 10       1...
# 34       0        29
# 8        24
# 9        24
# 10       1...
# 36       0        29
# 8        24
# 9        24
# 10       1...
# 37       0        29
# 8        24
# 9        24
# 10       1...
# 38       0        29
# 8        24
# 9        24
# 10       1...
# 39       0        29
# 8        24
# 9        24
# 10       1...
# 40       0        29
# 8        24
# 9        24
# 10       1...
# 42       0        29
# 8        24
# 9        24
# 10       1...
# 44       0        29
# 8        24
# 9        24
# 10       1...
# 47       0        29
# 8        24
# 9        24
# 10       1...
# 48       0        29
# 8        24
# 9        24
# 10       1...
# 51       0        29
# 8        24
# 9        24
# 10       1...
# 66       0        29
# 8        24
# 9        24
# 10       1...
# 74       0        29
# 8        24
# 9        24
# 10       1...
# 79       0        29
# 8        24
# 9        24
# 10       1...
# 86       0        29
# 8        24
# 9        24
# 10       1...
# 89       0        29
# 8        24
# 9        24
# 10       1...
# 105      0        29
# 8        24
# 9        24
# 10       1...
# 115      0        29
# 8        24
# 9        24
# 10       1...
# 117      0        29
# 8        24
# 9        24
# 10       1...
#                                ...
# 18498    0        29
# 8        24
# 9        24
# 10       1...
# 18502    0        29
# 8        24
# 9        24
# 10       1...
# 18533    0        29
# 8        24
# 9        24
# 10       1...
# 18536    0        29
# 8        24
# 9        24
# 10       1...
# 18564    0        29
# 8        24
# 9        24
# 10       1...
# 18602    0        29
# 8        24
# 9        24
# 10       1...
# 18608    0        29
# 8        24
# 9        24
# 10       1...
# 18643    0        29
# 8        24
# 9        24
# 10       1...
# 18661    0        29
# 8        24
# 9        24
# 10       1...
# 18662    0        29
# 8        24
# 9        24
# 10       1...
# 18671    0        29
# 8        24
# 9        24
# 10       1...
# 18717    0        29
# 8        24
# 9        24
# 10       1...
# 18722    0        29
# 8        24
# 9        24
# 10       1...
# 18742    0        29
# 8        24
# 9        24
# 10       1...
# 18761    0        29
# 8        24
# 9        24
# 10       1...
# 18768    0        29
# 8        24
# 9        24
# 10       1...
# 18773    0        29
# 8        24
# 9        24
# 10       1...
# 18794    0        29
# 8        24
# 9        24
# 10       1...
# 18799    0        29
# 8        24
# 9        24
# 10       1...
# 18818    0        29
# 8        24
# 9        24
# 10       1...
# 18821    0        29
# 8        24
# 9        24
# 10       1...
# 18893    0        29
# 8        24
# 9        24
# 10       1...
# 18894    0        29
# 8        24
# 9        24
# 10       1...
# 18896    0        29
# 8        24
# 9        24
# 10       1...
# 18930    0        29
# 8        24
# 9        24
# 10       1...
# 18934    0        29
# 8        24
# 9        24
# 10       1...
# 18940    0        29
# 8        24
# 9        24
# 10       1...
# 18951    0        29
# 8        24
# 9        24
# 10       1...
# 19027    0        29
# 8        24
# 9        24
# 10       1...
# 19170    0        29
# 8        24
# 9        24
# 10       1...
# Name: price, Length: 3751, dtype: object

# %%
df
# Out:
#              id neighbourhood_group_cleansed   price  \
# 0         11368                 Ciutat Vella   100.0
# 8         31823                     Eixample    75.0
# 9         31958                       Gràcia    65.0
# 10        32471                       Gràcia    95.0
# 11        32711                       Gràcia   140.0
# 19        40983                     Eixample    95.0
# 20        44868                 Ciutat Vella    82.0
# 26        58512                   Sant Martí   105.0
# 27        61444                     Eixample   105.0
# 28        66037                 Ciutat Vella   150.0
# 33        71553                     Eixample   110.0
# 34        71603                     Eixample   390.0
# 36        72436                   Sant Martí  1000.0
# 37        73455                 Ciutat Vella   120.0
# 38        73481                 Ciutat Vella    95.0
# 39        73643               Sants-Montjuïc   189.0
# 40        73649               Sants-Montjuïc   170.0
# 42        73692                     Eixample   105.0
# 44        73700               Sants-Montjuïc    65.0
# 47        75411                   Sant Martí   120.0
# 48        81291                   Sant Martí   139.0
# 51        89776                     Eixample    65.0
# 66       118126                       Gràcia    72.0
# 74       135513                   Sant Martí    80.0
# 79       144801                 Ciutat Vella    80.0
# 86       163490                     Eixample   160.0
# 89       171646                   Sant Martí   105.0
# 105      188267                     Eixample   316.0
# 115      199422                     Eixample    75.0
# 117      201958                 Ciutat Vella   100.0
# ...         ...                          ...     ...
# 18498  27274607                 Ciutat Vella   139.0
# 18502  27277006                 Ciutat Vella   100.0
# 18533  27298515                 Ciutat Vella   110.0
# 18536  27301414                     Eixample   118.0
# 18564  27332048                     Eixample    79.0
# 18602  27360919                 Ciutat Vella    80.0
# 18608  27366593          Sarrià-Sant Gervasi    80.0
# 18643  27390699                 Ciutat Vella   129.0
# 18661  27412549                     Eixample    80.0
# 18662  27412679                 Ciutat Vella    54.0
# 18671  27416511                 Ciutat Vella   139.0
# 18717  27429960                   Sant Martí   105.0
# 18722  27431333          Sarrià-Sant Gervasi   100.0
# 18742  27448863                     Eixample   100.0
# 18761  27454703                     Eixample    80.0
# 18768  27455998                 Ciutat Vella   130.0
# 18773  27457914                     Eixample    55.0
# 18794  27471887                 Ciutat Vella   160.0
# 18799  27472765                 Ciutat Vella   100.0
# 18818  27478388                       Gràcia   100.0
# 18821  27478975                       Gràcia   100.0
# 18893  27525612                     Eixample    89.0
# 18894  27525739                       Gràcia   129.0
# 18896  27526492                       Gràcia   100.0
# 18930  27546450                 Ciutat Vella   149.0
# 18934  27548984                     Eixample    35.0
# 18940  27551820                    Les Corts   119.0
# 18951  27561591                     Eixample   114.0
# 19027  27592558               Sants-Montjuïc   110.0
# 19170  27668483                     Eixample    95.0
#
#                          neighbourhood  accommodates  availability_30
# 0                                  NaN             4                1
# 8       La Nova Esquerra de l'Eixample             6                6
# 9      Camp d'en Grassot i Gràcia Nova             4                6
# 10     Camp d'en Grassot i Gràcia Nova             5               13
# 11     Camp d'en Grassot i Gràcia Nova             6               14
# 19                 Dreta de l'Eixample             4                3
# 20                            El Raval             2                4
# 26          El Camp de l'Arpa del Clot             6                3
# 27                 Dreta de l'Eixample             6               14
# 28                             El Born             6                7
# 33                 Dreta de l'Eixample             2                9
# 34                 Dreta de l'Eixample             3               30
# 36                         El Poblenou             2               23
# 37                            El Raval             5               14
# 38                            El Raval             2                5
# 39                        El Poble-sec             6               12
# 40                      Sants-Montjuïc             6               18
# 42                 Dreta de l'Eixample             5               12
# 44                        El Poble-sec             4                8
# 47                             El Clot             6               16
# 48                         El Poblenou             6                9
# 51                       el Fort Pienc             4                4
# 66                      Vila de Gràcia             2                6
# 74                         El Poblenou             5                5
# 79            Sant Pere/Santa Caterina             4               12
# 86                 Dreta de l'Eixample             6                1
# 89                             El Clot             6               16
# 105                Dreta de l'Eixample             5               24
# 115                      el Fort Pienc             6                5
# 117                           El Gòtic             4                0
# ...                                ...           ...              ...
# 18498                         El Raval             3               21
# 18502                         El Gòtic             3               10
# 18533                         El Raval             5                0
# 18536   La Nova Esquerra de l'Eixample             6               25
# 18564              Dreta de l'Eixample             2               16
# 18602                         El Gòtic             3               14
# 18608                El Putget i Farró             2               11
# 18643                         El Gòtic             4                3
# 18661   La Nova Esquerra de l'Eixample             5               17
# 18662                         El Gòtic             2                0
# 18671                         El Raval             3               23
# 18717            El Besòs i el Maresme             2                6
# 18722           Sant Gervasi - Galvany             3                0
# 18742                         El Raval             2               23
# 18761                      Sant Antoni             2               12
# 18768                         El Gòtic             2                1
# 18773                         El Raval             4               24
# 18794                         El Raval             4                4
# 18799                         El Raval             2                0
# 18818                   Vila de Gràcia             2                9
# 18821                   Vila de Gràcia             2               13
# 18893              Dreta de l'Eixample             2               18
# 18894                   Vila de Gràcia             2               14
# 18896                   Vila de Gràcia             2               11
# 18930                         El Gòtic             4               11
# 18934  L'Antiga Esquerra de l'Eixample             4                0
# 18940       La Maternitat i Sant Ramon             4               19
# 18951              Dreta de l'Eixample             3               21
# 19027                   Sants-Montjuïc             5               15
# 19170  L'Antiga Esquerra de l'Eixample             4                0
#
# [3751 rows x 6 columns]
