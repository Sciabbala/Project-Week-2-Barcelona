# %%
import pandas as pd
import numpy as np

from sqlalchemy import create_engine
import pymysql

# %%
connection = 'mysql+pymysql://root:ilikepizza@34.77.143.32/project2'

# %%
engine = create_engine(connection)

# %%
df = pd.read_csv('price_by_district.csv')

# %%
df.to_sql('airbnb', engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-261222eea359> in <module>
# ----> 1 df.to_sql('airbnb', engine)
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2529         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2530                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2531                    dtype=dtype, method=method)
#    2532
#    2533     def to_pickle(self, path, compression='infer',
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     458     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
# ...

# %%
query = '''
SELECT * FROM comparison'''

# %%
df = pd.read_sql(query, engine)

# %%
df
# Out:
#   neighbourhood_group_cleansed           id   price  accommodates  \
# 0                 Ciutat Vella  15032265.61  117.43          3.84
# 1                     Eixample  10664289.50  156.27          4.72
# 2                       Gràcia   9699926.23  135.86          4.23
# 3               Horta-Guinardó  12189816.85  157.97          4.25
# 4                    Les Corts  11242483.47  213.90          4.04
# 5                   Nou Barris   9425841.33   81.11          3.78
# 6                  Sant Andreu   9365560.50   80.86          4.36
# 7                   Sant Martí  11273150.72  134.58          4.63
# 8               Sants-Montjuïc  10012109.15  103.79          4.36
# 9          Sarrià-Sant Gervasi  10731520.99  143.10          4.02
#
#    availability_60  minimum_nights  revenue
# 0            18.11            4.59  2377.71
# 1            19.57            2.86  3017.02
# 2            18.49            3.18  2752.22
# 3            17.32            2.57  2811.40
# ...

# %%
import seaborn as sns

cm = sns.light_palette("seagreen", as_cmap=True)

s = df.style.background_gradient(cmap=cm, subset=['airbnb_revenue', 'airbnb_min_revenue', 'rent'])


s
# Out:
# <style  type="text/css" >
#     #T_7b785a4c_9f03_11e9_a308_b0c090b94abdrow0_col2 {
#             background-color:  #aad3bc;
#             color:  #000000;
#         }    #T_7b785a4c_9f03_11e9_a308_b0c090b94abdrow0_col3 {
#             background-color:  #98c8ad;
#             color:  #000000;
#         }    #T_7b785a4c_9f03_11e9_a308_b0c090b94abdrow0_col4 {
#             background-color:  #a0cdb4;
#             color:  #000000;
#         }    #T_7b785a4c_9f03_11e9_a308_b0c090b94abdrow1_col2 {
#             background-color:  #9dcbb1;
#             color:  #000000;
#         }    #T_7b785a4c_9f03_11e9_a308_b0c090b94abdrow1_col3 {
#             background-color:  #519f73;
#             color:  #000000;
#         }    #T_7b785a4c_9f03_11e9_a308_b0c090b94abdrow1_col4 {
#             background-color:  #81bb9b;
#             color:  #000000;
#         }    #T_7b785a4c_9f03_11e9_a308_b0c090b94abdrow2_col2 {
#             background-color:  #bbdcca;
#             color:  #000000;
# ...

# %%
columns = ['district', 'airbnb_revenue', 'rent']
comparison = pd.DataFrame(columns = columns)

# %%
comparison['district'] = df['neighbourhood_group_cleansed']

# %%
comparison['airbnb_revenue'] = df['revenue']

# %%
comparison['rent'] = rent['Preu']

# %%
comparison
# Out:
#               district  airbnb_revenue     rent
# 0         Ciutat Vella         2377.71   930.51
# 1             Eixample         3017.02  1038.47
# 2               Gràcia         2752.22   876.14
# 3       Horta-Guinardó         2811.40   764.27
# 4            Les Corts         3378.92  1313.60
# 5           Nou Barris         1638.33   660.98
# 6          Sant Andreu         2023.45   743.88
# 7           Sant Martí         2552.73   884.76
# 8       Sants-Montjuïc         2049.39   819.55
# 9  Sarrià-Sant Gervasi         2498.55  1335.04

# %%
comparison['pct_change'] = ((comparison['airbnb_revenue'] - comparison['rent'])/ comparison['rent']) * 100

# %%
comparison['pct_change'] = round(comparison['pct_change']/100, 2)

# %%
comparison
# Out:
#               district  airbnb_revenue     rent  pct_change
# 0         Ciutat Vella         2377.71   930.51      155.53
# 1             Eixample         3017.02  1038.47      190.53
# 2               Gràcia         2752.22   876.14      214.13
# 3       Horta-Guinardó         2811.40   764.27      267.85
# 4            Les Corts         3378.92  1313.60      157.23
# 5           Nou Barris         1638.33   660.98      147.86
# 6          Sant Andreu         2023.45   743.88      172.01
# 7           Sant Martí         2552.73   884.76      188.52
# 8       Sants-Montjuïc         2049.39   819.55      150.06
# 9  Sarrià-Sant Gervasi         2498.55  1335.04       87.15
